# %%
from textblob import TextBlob
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Suppress FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nrsmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\nrsmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\nrsmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nrsmi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### 3. Load the twentieth-century data that you scraped in Exercise 1.4

# %%
myfile = open('KeyEvents20thCentury_article_Wiki.txt', encoding='utf-8')

# %%
# Import txt file

with open('KeyEvents20thCentury_article_Wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

# %% [markdown]
# ### 4. Tokenize the words from the text and create a bar chart to plot the 10 most common words.

# %%
# Sentence tokenization

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['    Key events of the 20th century - Wikipedia                            Jump to content        Main menu      Main menu move to sidebar hide    \t\tNavigation \t   Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us      \t\tContribute \t   HelpLearn to editCommunity portalRecent changesUpload file                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in      \t\tPages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide     (Top)      1 Historic events in the 20th century     Toggle Historic events in the 20th century subsection      1.1 World at the beginning of the century       1.1.1 "The war to end all wars": World War I (1914â€“1918)         1.1.2 Russian Revolution and communism           1.2 Between the wars       1.2.1 Economic depression         1.2.2 The rise of dictatorship           1.3 Global war: World War II (1939â€“1945)       1.3.1 The war in Europe         1.3.2 Blitzkrieg         1.3.3 Operation Barbarossa         1.3.4 Turning tides         1.3.5 Operation Overlord         1.3.6 Final days         1.3.7 The war in the Pacific       1.3.7.1 Background           1.3.8 Japanese Expansion         1.3.9 Allied offensive         1.3.10 Final days         1.3.11 The Holocaust         1.3.12 The Nuclear Age begins           1.4 The post-war world       1.4.1 The end of empires: decolonization         1.4.2 The Cold War (1947â€“1991)         1.4.3 War by proxy         1.4.4 The space race         1.4.5 The end of the Cold War         1.4.6 Information and communications technology           1.5 The world at the end of the century           2 See also         3 References         4 Sources         5 External links                   Toggle the table of contents        Key events of the 20th century    2 languages     Ø§Ù„Ø¹Ø±Ø¨ÙŠØ©Ð£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide    \t\tActions \t   ReadEditView history      \t\tGeneral \t   What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened URLDownload QR code      \t\tPrint/export \t   Download as PDFPrintable version      \t\tIn other projects \t   Wikimedia CommonsWikidata item                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia    The 20th century changed the world in unprecedented ways.', 'The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created.', "These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.", 'Historic events in the 20th century[edit] World at the beginning of the century[edit] Main article: Edwardian era The new beginning of the 20th century marked significant changes.', 'The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.', '1914 saw the completion of the Panama Canal.', 'From 1914 to 1918, the First World War, and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.', '"The war to end all wars": World War I (1914â€“1918)[edit] Main article: World War I Arrest of a suspect in Sarajevo following the Assassination of Archduke Franz Ferdinand The First World War (or simply WWI), termed "The Great War" by contemporaries, started in July 1914 and ended in November 1918.', "The war was precipitated by the Assassination in Sarajevo of the Austro-Hungarian Empire's heir to the throne, Erzherzog Franz Ferdinand, by Gavrilo Princip, a member of the Young Bosnia liberation movement.", 'After a period o ...

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Key', 'events', 'of', 'the', '20th', 'century', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Historic', 'events', 'in', 'the', '20th', 'century', 'Toggle', 'Historic', 'events', 'in', 'the', '20th', 'century', 'subsection', '1.1', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '1.1.1', '``', 'The', 'war', 'to', 'end', 'all', 'wars', "''", ':', 'World', 'War', 'I', '(', '1914â€', '“', '1918', ')', '1.1.2', 'Russian', 'Revolution', 'and', 'communism', '1.2', 'Between', 'the', 'wars', '1.2.1', 'Economic', 'depression', '1.2.2', 'The', 'rise', 'of', 'dictatorship', '1.3', 'Global', 'war', ':', 'World', 'War', 'II', '(', '1939â€', '“', '1945', ')', '1.3.1', 'The', 'war', 'in', 'Europe', '1.3.2', 'Blitzkrieg', '1.3.3', 'Operation', 'Barbarossa', '1.3.4', 'Turning', 'tides', '1.3.5', 'Operation', 'Overlord', '1.3.6', 'Final', 'days', '1.3.7', 'The', 'war', 'in', 'the', 'Pacific', '1.3.7.1', 'Background', '1.3.8', 'Japanese', 'Expansion', '1.3.9', 'Allied', 'offensive', '1.3.10', 'Final', 'days', '1.3.11', 'The', 'Holocaust', '1.3.12', 'The', 'Nuclear', 'Age', 'begins', '1.4', 'The', 'post-war', 'world', '1.4.1', 'The', 'end', 'of', 'empires', ':', 'decolonization', '1.4.2', 'The', 'Cold', 'War', '(', '1947â€', '“', '1991', ')', '1.4.3', 'War', 'by', 'proxy', '1.4.4', 'The', 'space', 'race', '1.4.5', 'The', 'end', 'of', 'the', 'Cold', 'War', '1.4.6', 'Information', 'and', 'communications', 'technology', '1.5', 'The', 'world', 'at', 'the', 'end', 'of', 'the', 'century', '2', 'See', 'also', '3', 'References', '4', 'Sources', '5', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', 'Key', 'events', 'of', 'the', '20th', 'century', '2', 'languages', 'Ø§Ù', '„', 'Ø¹Ø±Ø¨ÙŠØ©Ð£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikimedia', 'CommonsWikidata', 'item', 'Appearance', 'move', 'to', 'sidebar', 'hide', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'The', '20th', 'century', 'changed', 'the', 'world', 'in', 'unprecedented', 'ways', '.', 'The', 'World', 'Wars', 'sparked', 'tension', 'between', 'countries', 'and', 'led', 'to', 'the', 'creation', 'of', 'atomic', 'bombs', ',', 'the', 'Cold', 'War', 'led', 'to', 'the', 'Space', 'Race', 'and', 'the', 'creation', 'of', 'space-based', 'rockets', ',', 'and', 'the', 'World', 'Wide', 'Web', 'was', 'created', '.', 'These', 'advancements', 'have', 'played', 'a', 'significant', 'role', 'in', 'citizens', "'", 'lives', 'and', 'shaped', 'the', '21st', 'century', 'into', 'what', 'it', 'is', 'today', '.', 'Historic', 'events', 'in', 'the', '20th', 'century', '[', 'edit', ']', 'World', 'at', 'the', 'beginning', 'of', 'the', 'century', '[', 'edit', ']', 'Main', 'article', ':', 'Edwardian', 'era', 'The', 'new', 'beginning', 'of', 'the', '20th', 'century', 'marked', 'significant', 'changes', '.', 'The', '1900s', 'saw', 'the', 'decade', 'herald', 'a', 'series', 'of', 'inventions', ',', 'including', 'the', 'automobile', ',', 'airplane', 'and', 'radio', 'broadcasting', '.', '1914', 'saw', 'the', 'completion', 'of', 'the', 'Panama', 'Canal', ...

# %%
word_counts = Counter(tokenized_word)
most_common_words = word_counts.most_common(10)

# %%
common_words_df = pd.DataFrame(most_common_words, columns=["Word", "Count"])

# %%
plt.figure(figsize=(10, 6))
palette = sns.dark_palette("xkcd:blue", n_colors=len(common_words_df), reverse=False)
sns.barplot(data=common_words_df, x="Count", y="Word", palette=palette)
plt.title("Top 10 Most Common Words")
plt.xlabel("Frequency")
plt.ylabel("Words")
plt.show()

# %% [markdown]
# ### 5. Remove stop words (and punctuation marks if necessary), and rerun the plot. What has changed? Comment on your impressions in a markdown cell under the plot.

# %%
# Create frequency distribution

from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 4797 samples and 21734 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('.', 1559),
#  ('the', 1095),
#  (',', 958),
#  ('of', 606),
#  ('and', 398),
#  ('to', 324),
#  ('The', 323),
#  ('[', 300),
#  (']', 300),
#  ('in', 291)]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words("english"))

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
      if word not in stop_words:
           filtered_words.append(word)

# %%
# Create a new FreqDist for filtered–words

dist_words_filter = FreqDist(filtered_words)
print (dist_words_filter)
# Out:
# <FreqDist with 4694 samples and 17083 outcomes>

# %%
# Substitute all punctuation marks with a space

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_words))

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
#print (tokenized_word_2)

# %%
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Count the most common filtered words
word_counts_filtered = dist_words_filter_2.most_common(10)

# %%
# Create a DataFrame for visualization
filtered_words_df = pd.DataFrame(word_counts_filtered, columns=["Word", "Count"])
filtered_words_df
# Out:
#         Word  Count
# 0        The    324
# 1   December    220
# 2  Retrieved    204
# 3        War    127
# 4          s    101
# 5        war     91
# 6         th     87
# 7      World     77
# 8     Soviet     61
# 9     Hitler     51

# %%
plt.figure(figsize=(10, 6))
palette = sns.dark_palette("xkcd:blue", n_colors=len(common_words_df), reverse=False)
sns.barplot(data=filtered_words_df, x="Count", y="Word", palette=palette)
plt.title("Top 10 Most Common Words (Excluding Stopwords and Punctuation)")
plt.xlabel("Frequency")
plt.ylabel("Words")
plt.show()

# %% [markdown]
# #### Before removing stopwords and punctuation, the most common words were basic words like "the," "and," and symbols like commas and periods, which don't tell us much about the text's meaning. After removing them, the results focused on important words like "war," "world," and "Soviet," which better represent the main topics of the text. This makes it easier to understand what the text is really about.

# %% [markdown]
# ### 6. Create a tags list using TextBlob.

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

filtered = []
for word in tokenized_word_2:
     if word not in new_stopwords:
        filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: total: 0 ns
# Wall time: 5.98 ms

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Jump", 'NNP'),
#  ("'", 'POS'),
#  ("'content", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'us", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'file", 'IN'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Personal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'Contents", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'Economic", 'NNP'),
#  ("'", 'POS'),
#  ("'depression", 'NN'),
#  ("'rise", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Blitzkrieg", 'NNP'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Turning", 'VBG'),
#  ("'tides", 'NNS'),
#  ("'", 'POS'),
#  ("'Operation", 'NN'),
#  ("'Overlord", 'NNP'),
#  ("'", 'POS'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Pacific", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'Japanese", 'JJ'),
#  ("'Expansion", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'offensive", 'CD'),
#  ("'Final", 'NNP'),
#  ("'", 'POS'),
#  ("'days", 'NNS'),
#  ("'", 'POS'),
#  ("'Holocaust", 'NNP'),
#  ("'", 'POS'),
#  ("'Age", 'NNP'),
#  ("'", 'POS'),
#  ("'begins", 'NNS'),
#  ("'", 'POS'),
#  ("'post", 'FW'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'decolonization", 'NN'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'proxy", 'NNP'),
#  ("'", 'POS'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'race", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'Information", 'NN'),
#  ("'communications", 'NNS'),
#  ("'", 'POS'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Sources", 'NNS'),
#  ("'", 'POS'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'Key", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pagesPermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'code", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikimedia", 'NNP'),
#  ("'", 'POS'),
#  ("'CommonsWikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopedia", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'changed", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'unprecedented", 'VBD'),
#  ("'ways", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wars", 'NNS'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'tension", 'NNP'),
#  ("'", 'POS'),
#  ("'countries", 'NNS'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'creation", 'NNP'),
#  ("'", 'POS'),
#  ("'atomic", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'led", 'VBD'),
#  ("'Space", 'NNP'),
#  ("'", 'POS'),
#  ("'Race", 'NNP'),
#  ("'", 'POS'),
#  ("'creation", 'NN'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'rockets", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'Wide", 'NNP'),
#  ("'", 'POS'),
#  ("'Web", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'These", 'JJ'),
#  ("'advancements", 'NNS'),
#  ("'", 'POS'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'role", 'NNP'),
#  ("'", 'POS'),
#  ("'citizens", 'NNS'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'shaped", 'VBD'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Edwardian", 'JJ'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'marked", 'VBD'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'herald", 'NNP'),
#  ("'", 'POS'),
#  ("'series", 'NNS'),
#  ("'", 'POS'),
#  ("'inventions", 'NNS'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'automobile", 'IN'),
#  ("'airplane", 'NNP'),
#  ("'", 'POS'),
#  ("'radio", 'NNP'),
#  ("'", 'POS'),
#  ("'broadcasting", 'VBG'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'completion", 'NN'),
#  ("'Panama", 'NNP'),
#  ("'", 'POS'),
#  ("'Canal", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'aftermath", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'changes", 'NNS'),
#  ("'", 'POS'),
#  ("'power", 'NNP'),
#  ("'", 'POS'),
#  ("'balance", 'NN'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'destroying", 'VBG'),
#  ("'transforming", 'VBG'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'Arrest", 'JJS'),
#  ("'suspect", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'following", 'VBG'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Archduke", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'simply", 'NNP'),
#  ("'", 'POS'),
#  ("'WWI", 'NNP'),
#  ("'", 'POS'),
#  ("'termed", 'VBD'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'contemporaries", 'NNS'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'November", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'precipitated", 'VBD'),
#  ("'Assassination", 'NNP'),
#  ("'", 'POS'),
#  ("'Sarajevo", 'NNP'),
#  ("'", 'POS'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'throne", 'CD'),
#  ("'Erzherzog", 'NNP'),
#  ("'", 'POS'),
#  ("'Franz", 'NNP'),
#  ("'", 'POS'),
#  ("'Ferdinand", 'NNP'),
#  ("'", 'POS'),
#  ("'Gavrilo", 'NNP'),
#  ("'", 'POS'),
#  ("'Princip", 'NNP'),
#  ("'", 'POS'),
#  ("'member", 'NNP'),
#  ("'", 'POS'),
#  ("'Young", 'NNP'),
#  ("'", 'POS'),
#  ("'Bosnia", 'NNP'),
#  ("'", 'POS'),
#  ("'liberation", 'NN'),
#  ("'movement", 'NNP'),
#  ("'", 'POS'),
#  ("'After", 'NNP'),
#  ("'", 'POS'),
#  ("'period", 'NNP'),
#  ("'", 'POS'),
#  ("'diplomatic", 'JJ'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'escalation", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'Crisis", 'NN'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'two", 'NNP'),
#  ("'", 'POS'),
#  ("'coalitions", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'Allies", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'France", 'NN'),
#  ("'Russian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'comprised", 'VBD'),
#  ("'initially", 'RB'),
#  ("'", 'POS'),
#  ("'German", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'hostile", 'IN'),
#  ("'actions", 'NNS'),
#  ("'", 'POS'),
#  ("'Central", 'NNP'),
#  ("'", 'POS'),
#  ("'Powers", 'NNS'),
#  ("'", 'POS'),
#  ("'Tsar", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolsheviks", 'NNP'),
#  ("'", 'POS'),
#  ("'negotiated", 'VBD'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Brest", 'JJS'),
#  ("'Litovsk", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Bolshevik", 'NNP'),
#  ("'", 'POS'),
#  ("'ceded", 'VBD'),
#  ("'Baltic", 'JJ'),
#  ("'states", 'VBZ'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'province", 'NN'),
#  ("'Kars", 'NNS'),
#  ("'", 'POS'),
#  ("'South", 'NNP'),
#  ("'", 'POS'),
#  ("'Caucasus", 'NNP'),
#  ("'", 'POS'),
#  ("'Ottoman", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'recognized", 'VBN'),
#  ("'independence", 'NNP'),
#  ("'", 'POS'),
#  ("'Ukraine", 'NNP'),
#  ("'", 'POS'),
#  ("'Although", 'IN'),
#  ("'", 'POS'),
#  ("'shifted", 'VBD'),
#  ("'forces", 'NNS'),
#  ("'", 'POS'),
#  ("'eastern", 'NNP'),
#  ("'", 'POS'),
#  ("'western", 'NNP'),
#  ("'", 'POS'),
#  ("'front", 'NNP'),
#  ("'", 'POS'),
#  ("'signing", 'VBG'),
#  ("'treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'unable", 'JJ'),
#  ("'stop", 'NNP'),
#  ("'", 'POS'),
#  ("'Allied", 'VBD'),
#  ("'advance", 'NNP'),
#  ("'", 'POS'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'entrance", 'NN'),
#  ("'American", 'JJ'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'combatant", 'NNP'),
#  ("'", 'POS'),
#  ("'nations", 'NNS'),
#  ("'", 'POS'),
#  ("'show", 'NNP'),
#  ("'", 'POS'),
#  ("'military", 'NNP'),
#  ("'", 'POS'),
#  ("'strength", 'NNP'),
#  ("'", 'POS'),
#  ("'technological", 'JJ'),
#  ("'ingenuity", 'NNP'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'introduced", 'VBD'),
#  ("'machine", 'NNP'),
#  ("'", 'POS'),
#  ("'gun", 'NNP'),
#  ("'", 'POS'),
#  ('U', 'NNP'),
#  ("'", 'POS'),
#  ("'boats", 'NNS'),
#  ("'", 'POS'),
#  ("'deadly", 'RB'),
#  ("'gases", 'NNS'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'used", 'VBD'),
#  ("'tank", 'NNP'),
#  ("'", 'POS'),
#  ("'Both", 'NNP'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'chance", 'NN'),
#  ("'test", 'JJS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'aircraft", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'used", 'VBD'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'widely", 'RB'),
#  ("'believed", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'short", 'NNP'),
#  ("'", 'POS'),
#  ("'Unfortunately", 'RB'),
#  ("'since", 'NNP'),
#  ("'", 'POS'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'best", 'JJS'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'sides", 'NNS'),
#  ("'", 'POS'),
#  ("'slow", 'NNP'),
#  ("'", 'POS'),
#  ("'terrible", 'JJ'),
#  ("'cost", 'FW'),
#  ("'", 'POS'),
#  ("'lives", 'NNS'),
#  ("'", 'POS'),
#  ("'Division", 'NN'),
#  ("'Austria", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungary", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'When", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'finally", 'RB'),
#  ("'", 'POS'),
#  ("'results", 'NNS'),
#  ("'", 'POS'),
#  ("'would", 'MD'),
#  ("'set", 'NNP'),
#  ("'", 'POS'),
#  ("'stage", 'NN'),
#  ("'twenty", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'foremost", 'FW'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'forced", 'VBD'),
#  ("'sign", 'NNP'),
#  ("'", 'POS'),
#  ("'Treaty", 'NNP'),
#  ("'", 'POS'),
#  ("'Versailles", 'NNS'),
#  ("'", 'POS'),
#  ("'forcing", 'VBG'),
#  ("'make", 'NNP'),
#  ("'", 'POS'),
#  ("'exorbitant", 'NNP'),
#  ("'", 'POS'),
#  ("'payments", 'NNS'),
#  ("'", 'POS'),
#  ("'repair", 'NNP'),
#  ("'", 'POS'),
#  ("'damages", 'NNS'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'Germans", 'NNS'),
#  ("'", 'POS'),
#  ("'felt", 'NNP'),
#  ("'", 'POS'),
#  ("'reparations", 'NNS'),
#  ("'", 'POS'),
#  ("'unfair", 'NNP'),
#  ("'", 'POS'),
#  ("'actually", 'RB'),
#  ("'", 'POS'),
#  ("'lose", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'feel", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'in", 'NNP'),
#  ("'", 'POS'),
#  ("'the", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'occupied", 'VBD'),
#  ("'Allied", 'VBD'),
#  ("'troops", 'NNS'),
#  ("'", 'POS'),
#  ("'yet", 'NNP'),
#  ("'", 'POS'),
#  ("'accept", 'IN'),
#  ("'liberal", 'NNP'),
#  ("'", 'POS'),
#  ("'democratic", 'JJ'),
#  ("'government", 'NNP'),
#  ("'", 'POS'),
#  ("'imposed", 'VBD'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'abdication", 'NN'),
#  ("'Kaiser", 'NNP'),
#  ("'", 'POS'),
#  ("'Wilhelm", 'NNP'),
#  ("'", 'POS'),
#  ("'Much", 'JJ'),
#  ("'map", 'NNP'),
#  ("'", 'POS'),
#  ("'redrawn", 'NNP'),
#  ("'", 'POS'),
#  ("'victors", 'NNS'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'theory", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'could", 'MD'),
#  ("'prevented", 'VBD'),
#  ("'ethnic", 'NNP'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'homeland", 'NNP'),
#  ("'", 'POS'),
#  ("'New", 'NNP'),
#  ("'", 'POS'),
#  ("'states", 'NNS'),
#  ("'", 'POS'),
#  ("'like", 'IN'),
#  ("'Yugoslavia", 'NNP'),
#  ("'", 'POS'),
#  ("'Czechoslovakia", 'NNP'),
#  ("'", 'POS'),
#  ("'created", 'VBD'),
#  ("'Austro", 'NNP'),
#  ("'", 'POS'),
#  ("'Hungarian", 'JJ'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'accommodate", 'NNP'),
#  ("'", 'POS'),
#  ("'aspirations", 'NNS'),
#  ("'", 'POS'),
#  ("'groups", 'NNS'),
#  ("'", 'POS'),
#  ("'An", 'NNP'),
#  ("'", 'POS'),
#  ("'international", 'NNP'),
#  ("'", 'POS'),
#  ("'body", 'NN'),
#  ("'called", 'VBD'),
#  ("'League", 'NNP'),
#  ("'", 'POS'),
#  ("'Nations", 'NNS'),
#  ("'", 'POS'),
#  ("'formed", 'VBD'),
#  ("'mediate", 'NNP'),
#  ("'", 'POS'),
#  ("'disputes", 'NNS'),
#  ("'", 'POS'),
#  ("'prevent", 'NNP'),
#  ("'", 'POS'),
#  ("'future", 'NN'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'effectiveness", 'NNP'),
#  ("'", 'POS'),
#  ("'severely", 'RB'),
#  ("'limited", 'VBD'),
#  ("'among", 'NNP'),
#  ("'", 'POS'),
#  ("'things", 'NNS'),
#  ("'", 'POS'),
#  ("'reluctance", 'NN'),
#  ("'inability", 'NNP'),
#  ("'", 'POS'),
#  ("'act", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'communism", 'NN'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'article", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'Russian", 'JJ'),
#  ("'Revolution", 'NNP'),
#  ("'", 'POS'),
#  ("'ending", 'VBG'),
#  ("'regime", 'NNP'),
#  ("'", 'POS'),
#  ("'execution", 'NN'),
#  ("'His", 'NNP'),
#  ("'", 'POS'),
#  ("'Imperial", 'NNP'),
#  ("'", 'POS'),
#  ("'Majesty", 'NNP'),
#  ("'", 'POS'),
#  ("'Nicholas", 'NNS'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'family", 'RB'),
#  ("'", 'POS'),
#  ("'sparked", 'VBD'),
#  ("'wave", 'NNP'),
#  ("'", 'POS'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'across", 'IN'),
#  ("'prompting", 'VBG'),
#  ("'", 'POS'),
#  ("'believe", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'could", 'MD'),
#  ("'realized", 'VBN'),
#  ("'near", 'IN'),
#  ("'future", 'NN'),
#  ("'revolutions", 'NNS'),
#  ("'", 'POS'),
#  ("'defeated", 'VBD'),
#  ("'Vladimir", 'NNP'),
#  ("'", 'POS'),
#  ("'Lenin", 'NNP'),
#  ("'", 'POS'),
#  ("'died", 'VBD'),
#  ("'within", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'Joseph", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'displaced", 'VBD'),
#  ("'Leon", 'NNP'),
#  ("'", 'POS'),
#  ("'Trotsky", 'NNP'),
#  ("'", 'POS'),
#  ("'de", 'NNP'),
#  ("'", 'POS'),
#  ("'facto", 'NNP'),
#  ("'", 'POS'),
#  ("'Soviet", 'NNP'),
#  ("'", 'POS'),
#  ("'Union", 'NN'),
#  ("'idea", 'NNP'),
#  ("'", 'POS'),
#  ("'worldwide", 'NNP'),
#  ("'", 'POS'),
#  ("'revolution", 'NN'),
#  ("'longer", 'NNP'),
#  ("'", 'POS'),
#  ("'forefront", 'NNP'),
#  ("'", 'POS'),
#  ("'Stalin", 'NNP'),
#  ("'", 'POS'),
#  ("'concentrated", 'VBD'),
#  ("'socialism", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'country", 'NNP'),
#  ("'", 'POS'),
#  ("'embarked", 'VBD'),
#  ("'plan", 'NNP'),
#  ("'", 'POS'),
#  ("'collectivization", 'NN'),
#  ("'industrialization", 'NNP'),
#  ("'", 'POS'),
#  ("'majority", 'NNP'),
#  ("'", 'POS'),
#  ("'socialists", 'NNS'),
#  ("'", 'POS'),
#  ...]

# %% [markdown]
# ### 7. Create a list of the Top 10 POS tags for words that appear in the article.

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]

# %%
df_text.head()
# Out:
#      Words Word type
# 0        [        JJ
# 1     'Key       NNP
# 2        '       POS
# 3  'events       NNS
# 4        '       POS

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      1
# 1        CD     75
# 2        DT     12
# 3        EX     12
# 4        FW     43

# %%
top10 = df_t.nlargest(10, 'Words')

# %%
top10
# Out:
#    Word type  Words
# 13       POS   6952
# 11       NNP   5653
# 12       NNS   1045
# 16       VBD    845
# 10        NN    385
# 17       VBG    319
# 6         JJ    285
# 5         IN    155
# 15        RB    141
# 20       VBZ     79

# %% [markdown]
# ### 8. Plot this list in a bar chart using the seaborn library.

# %%
plt.figure(figsize = (10, 5))
palette = sns.dark_palette("xkcd:blue", n_colors=len(common_words_df), reverse=False)
with sns.dark_palette("xkcd:blue", 20):
      sns.barplot(x = "Words", y = "Word type", palette = palette,
     saturation = 0.9, data = top10).set_title("Key Events 20th Century Wiki Article - top 10 word types used")

# %% [markdown]
# ### 9. Create three bar plots with the top 15 POS labels—one each for nouns, verbs, and adjectives. Analyzing the results—what do you think stands out in these frequencies? Comment on your impressions in a Markdown cell under the plot.

# %% [markdown]
# #### Nouns

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15_noun = y.nlargest(15, 'Occurences')

# %%
top15_noun
# Out:
#            Word  Occurences
# 295   'December         220
# 1260       'War         127
# 2574       'war          91
# 2494        'th          87
# 1306     'World          77
# 1107    'Soviet          61
# 539     'Hitler          51
# 538    'History          41
# 1494   'century          40
# 561       'ISBN          39
# 2607       'www          38
# 1778     'first          38
# 572         'In          37
# 2600     'world          37
# 477     'German          35

# %%
plt.figure(figsize=(10, 5))
palette = sns.dark_palette("xkcd:blue", n_colors=len(top15_noun), reverse=False)
with sns.dark_palette("xkcd:blue", 15):
    sns.barplot(x="Word", y="Occurences", palette=palette,
    saturation=0.9, data = top15_noun).set_title("Key Events 20th Century Wiki Article - Top 15 most frequently used nouns")

# %% [markdown]
# #### Verbs

# %%
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top15_verb = y.nlargest(15, 'Occurences')

# %%
top15_verb
# Out:
#              Word  Occurences
# 26     'Retrieved         204
# 35        'United          30
# 0         'Allied          19
# 192          'led          15
# 313         'used          13
# 190     'launched          12
# 1       'Archived          10
# 91    'controlled           9
# 158       'forced           8
# 297  'surrendered           7
# 75       'changed           7
# 305       'turned           7
# 227      'planned           6
# 291     'suffered           6
# 97       'created           6

# %%
plt.figure(figsize = (10, 5))
palette = sns.dark_palette("xkcd:blue", n_colors=len(top15_verb), reverse=False)
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x = "Word", y = "Occurences", palette=palette,
    saturation = 0.9, data = top15_verb).set_title(" Key Events 20th Century Wiki Article - Top 15 most frequently used verbs")
    plt.xticks(rotation=45)

# %% [markdown]
# #### Adjectives

# %%
df = df_text[df_text['Word type'] == "JJ"]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by=['Occurences'], ascending=False)
top15_adjective = y.nlargest(15, 'Occurences')

# %%
top15_adjective
# Out:
#             Word  Occurences
# 27     'Japanese          36
# 2      'American          24
# 5      'Atlantic          13
# 19     'Guardian          10
# 13      'Chinese           7
# 42      'Russian           7
# 1       'African           6
# 103   'political           6
# 104    'possible           5
# 7        'Baltic           5
# 50        'These           4
# 9         'Brian           4
# 26      'Italian           4
# 6    'Australian           4
# 91      'medical           4

# %%
plt.figure(figsize=(10, 5))
palette = sns.dark_palette("xkcd:blue", n_colors=len(top15_adjective), reverse=False)
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x="Word", y="Occurences", palette=palette,
    saturation=0.9, data=top15_adjective).set_title("Key Events 20th Century Wiki Article - Top 15 most frequently used adjectives")
    plt.xticks(rotation=45)

# %% [markdown]
# ##### The charts show that the most common adjectives, like "Japanese" and "American," reflect a focus on countries and regions involved in major events of the 20th century. The verbs, such as "Retrieved," "United," and "Launched," highlight important actions like alliances, treaties, and historical milestones. The nouns, including "War," "World," and "Soviet," clearly point to key themes like WWII, the Cold War, and influential figures. Overall, these words emphasize the significant events, places, and actions that shaped 20th-century history.

# %% [markdown]
# ### 10. Create a dataframe with the countries and the number of times they’re mentioned in your text

# %%
listToStr = ' '.join([str(elem) for elem in filtered])
print(listToStr)
# Out:
# Key events th century Wikipedia Jump content Main menu Main menu move sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us Contribute HelpLearn editCommunity portalRecent changesUpload file Search Search Appearance Donate Create account Log Personal tools Donate Create account Log Pages logged editors learn ContributionsTalk Contents move sidebar hide Top Historic events th century Toggle Historic events th century subsection World beginning century war end wars World War I Russian Revolution communism Between wars Economic depression rise dictatorship Global war World War II war Europe Blitzkrieg Operation Barbarossa Turning tides Operation Overlord Final days war Pacific Background Japanese Expansion Allied offensive Final days Holocaust Nuclear Age begins post war world end empires decolonization Cold War War proxy space race end Cold War Information communications technology world end century See also References Sources External links Toggle table contents Key events th century languages Edit links ArticleTalk English ReadEditView history Tools Tools move sidebar hide Actions ReadEditView history General What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite pageGet shortened URLDownload QR code Print export Download PDFPrintable version In projects Wikimedia CommonsWikidata item Appearance move sidebar hide From Wikipedia free encyclopedia th century changed world unprecedented ways World Wars sparked tension countries led creation atomic bombs Cold War led Space Race creation space based rockets World Wide Web created These advancements played significant role citizens lives shaped st century today Historic events th century edit World beginning century edit Main article Edwardian era new beginning th century marked significant changes saw decade herald series inventions including automobile airplane radio broadcasting saw completion Panama Canal From First World War aftermath caused major changes power balance world destroying transforming powerful empires war end wars World War I edit Main article World War I Arrest suspect Sarajevo following Assassination Archduke Franz Ferdinand First World War simply WWI termed Great War contemporaries started July ended November war precipitated Assassination Sarajevo Austro Hungarian Empire heir throne Erzherzog Franz Ferdinand Gavrilo Princip member Young Bosnia liberation movement After period diplomatic military escalation known July Crisis end July two coalitions war Allies comprised initially British Empire France Russian Empire Central Powers comprised initially German Empire Austria Hungary In Russia ended hostile actions Central Powers fall Tsar Bolsheviks negotiated Treaty Brest Litovsk Germany although huge cost Russia In treaty Bolshevik Russia ceded Baltic states Germany province Kars Oblast South Caucasus Ottoman Empire It also recognized independence Ukraine Although Germany shifted huge forces eastern western front signing treaty unable stop Allied advance especially entrance American troops war also chance combatant nations show military strength technological ingenuity Germans introduced machine gun U boats deadly gases British first used tank Both sides chance test new aircraft see could used warfare It widely believed war would short Unfortunately since trench warfare best form defense advances sides slow came terrible cost lives Division Austria Hungary World War I When war finally results would set stage next twenty years First foremost Germans forced sign Treaty Versailles forcing make exorbitant payments repair damages caused War Many Germans felt reparations unfair actually lose war feel caused war see Stab in the back legend Germany never occupied Allied troops yet accept liberal democratic government imposed victors abdication Kaiser Wilhelm Much map Europe redrawn victors based upon theory future wars could prevented ethnic groups homeland New states like Yugoslavia Czechoslovaki ...

# %%
# Create a count for the countries

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
countries = pd.read_csv("countries_list.csv")
countries.head()
# Out:
#                  Country
# 0               Abkhazia
# 1                 Adjara
# 2            Afghanistan
# 3  Akrotiri and Dhekelia
# 4                Albania

# %%
cntry_list = countries['Country'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in cntry_list}

# %%
#Search for the names from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Abkhazia  Adjara  Afghanistan  Akrotiri and Dhekelia  Albania  Algeria  \
# 0         0       0            1                      0        2        1
#
#    American Samoa  Andorra  Angola  Anguilla  ...  Venezuela  Vietnam  \
# 0               0        0       1         0  ...          0       13
#
#    Wa State  Wales  West Papua  Yemen  Zambia  Zimbabwe  sovereign states  \
# 0         0      0           0      0       0         0                 0
#
#    Ãland
# 0      0
#
# [1 rows x 283 columns]

# %%
df = df.transpose().reset_index()
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df
# Out:
#                      index  0
# 0                 Abkhazia  0
# 1                   Adjara  0
# 2              Afghanistan  1
# 3    Akrotiri and Dhekelia  0
# 4                  Albania  2
# ..                     ... ..
# 277                  Yemen  0
# 278                 Zambia  0
# 279               Zimbabwe  0
# 280       sovereign states  0
# 281                  Ãland  0
#
# [282 rows x 2 columns]

# %%
df.rename(columns = {"index":"Country", 0:"Times mentioned"}, inplace = True)

# %%
df
# Out:
#                    Country  Times mentioned
# 0                 Abkhazia                0
# 1                   Adjara                0
# 2              Afghanistan                1
# 3    Akrotiri and Dhekelia                0
# 4                  Albania                2
# ..                     ...              ...
# 277                  Yemen                0
# 278                 Zambia                0
# 279               Zimbabwe                0
# 280       sovereign states                0
# 281                  Ãland                0
#
# [282 rows x 2 columns]

# %%
mentions_df = df.sort_values(by='Times mentioned', ascending=False).reset_index(drop=True)

# %%
mentions_df.head()
# Out:
#    Country  Times mentioned
# 0  Germany               42
# 1    Japan               33
# 2   France               16
# 3    Italy               14
# 4   Poland               13

# %% [markdown]
# ### 11. Create a plot showing the frequency of the number of times these countries are mentioned in the text. Is there anything in particular you notice in this plot? Describe your findings in a Markdown cell underneath the plot.

# %%
# Drop rows where 'Mentions' is 0
mentions_df2 = mentions_df.loc[mentions_df['Times mentioned'] > 0].reset_index(drop=True)
mentions_df2
# Out:
#         Country  Times mentioned
# 0       Germany               42
# 1         Japan               33
# 2        France               16
# 3         Italy               14
# 4        Poland               13
# 5       Vietnam               13
# 6         China               10
# 7         India                9
# 8        Russia                9
# 9   Philippines                5
# 10       Norway                5
# 11        Libya                5
# 12      Austria                5
# 13      Finland                4
# 14     Pakistan                4
# 15         Iran                4
# 16       Guinea                4
# 17       Greece                4
# 18       Israel                4
# 19         Cuba                3
# 20      Romania                3
# 21      Hungary                3
# 22         Guam                3
# 23      Denmark                3
# 24    Lithuania                3
# 25      Ukraine                2
# 26        Egypt                2
# 27      Belgium                2
# 28       Latvia                2
# 29      Estonia                2
# 30  Netherlands                2
# 31      Albania                2
# 32    Singapore                2
# 33     Cambodia                2
# 34    Australia                2
# 35       Canada                2
# 36   Bangladesh                2
# 37     Mongolia                1
# 38      Morocco                1
# 39   Mozambique                1
# 40      Belarus                1
# 41         Iraq                1
# 42     Bulgaria                1
# 43       Panama                1
# 44       Angola                1
# 45      Algeria                1
# 46  Afghanistan                1
# 47        Ghana                1
# 48   Seychelles                1
# 49         Laos                1
# 50        Spain                1
# 51       Sweden                1
# 52     Thailand                1
# 53      Lebanon                1
# 54        Kenya                1
# 55   Luxembourg                1
# 56       Mexico                1

# %%
plt.figure(figsize=(10, 15))
palette = sns.dark_palette("#79C", n_colors=len(mentions_df2), reverse=False)
with sns.dark_palette("#79C", 27):
    sns.barplot(x = "Times mentioned", y = "Country", palette=palette,
    saturation=0.9, data = mentions_df2.sort_values("Times mentioned", ascending = False)).set_title("Key Events 20th Century Wiki Article - most frequently mentioned countries")

# %% [markdown]
# #### The plot shows that Germany, Japan, and France are the most mentioned countries, reflecting their key roles in major 20th-century events like World Wars and global conflicts. Countries from around the world are included, highlighting the global impact of these events. However, the absence of the United States, despite its significant role in events like the World Wars and the Cold War, is surprising. This suggests the need for further research to determine if the United States is being referred to by another name, such as "America" or "US."
